# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/153d9186-5292-438b-94ca-ab9a8134f4d0.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/10fc3464-bb8b-45fb-9861-b79d288e2368.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1a70a918-bcde-4eca-806f-d875867a1a01.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2037ee0c-2b69-43fc-b155-efbd79c0d644.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2228940d-d9f1-4f96-820d-baae56f766d4.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/214e0545-1efa-4fe8-a884-a778473e4671.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0df38bf0-24eb-4e29-947f-02d95fd984c9.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/11c0eec2-1878-4f9f-b73a-e3bee3a62173.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/03dfd775-0cb4-4ede-9eba-e01df8a84965.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/11ba8217-4fcc-4da8-a748-476260d6b3c6.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0133a3a9-350d-4501-a59f-6a7e74fbc1c8.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/21b094d6-593d-4dc2-a53f-c8edf0ce4f59.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1ae4aec3-f102-47a2-94a3-a59503f450f7.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/10a58805-abdf-4bd1-80bd-b76f8dd5c4f9.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0dd5582d-16a6-41a8-b06b-8d15325d34a6.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/26bf3493-da59-49e0-a702-eaa7bf823a91.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/21a34cf2-823f-4699-8286-43931ef708cf.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/142126cc-d94d-4df6-85bc-a980c18013b3.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/03858c3a-5c32-4503-8888-58f2f601c1df.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/bfff5d71-87ab-4530-beb9-ff017b6160a7.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1bfc882d-8bb0-4032-820a-4c34e5790ad6.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/031cc0e4-9e42-4bfe-9d0c-fb3170cfdc2f.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/126d9f1a-7dfe-4616-a917-57499b15d9bf.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/237d16b3-0c02-47e5-88a8-a7e03a74a808.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1d78c3f0-7511-4ee1-9081-1d101aaf751e.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/11b086d8-f29b-4809-ae14-747dfd3d59b5.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/313ce9b9-3fe4-4354-aea7-707eee7db3ab.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2602635c-7751-44db-82b3-ea47dd399121.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/14291892-506f-4f4d-8dca-57f456d2ba57.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2d5d0fc8-314d-41bd-adfd-52f1a1e3cc5c.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/14c691a4-e50b-4780-8511-a45510f5d6e7.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/19a439ff-6521-4bea-9179-dccef727f918.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/04785916-0ae2-40b9-bd71-1698025326fa.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/033af663-f044-43ab-a569-298cc4bf37bc.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2e929adc-551d-426c-a25d-2d767ccb0c18.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0580d4c0-6700-467a-a81b-f39d3d037884.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1b134dac-2562-4ecd-872c-71c7c07e83f0.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/25df7025-79bf-4b6f-8b58-dcb1268e1a22.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/032d8361-e8b5-4e8a-905a-9fae58f42398.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0dfe304d-a5b6-43b7-969e-754c6ebd7747.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/003fbda2-ba55-4714-a03a-83f15bec19e4.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/30ec2070-83bc-4698-8913-9ec89516940e.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/00860e86-5b18-4694-a20a-0b47e842a453.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2d5d8ecc-3ee3-4c9b-bb86-3f614a079585.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2a17e36f-a43c-44f8-bf50-9d36f7d5cfae.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1aefa92d-c179-4ced-8006-0df6892abf17.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2ba33562-3b2a-4d4b-9a8d-2da5100c2a9d.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/11070900-23ad-491a-9c16-fb4dce0091ee.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/129459d4-fbde-469b-b038-6f5fd9ab05e2.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/10cdb6ec-b1e9-45ec-a3f3-2364dd30346b.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/03a4ba96-d15e-4fb0-bcc5-a2987916786a.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2d281227-f786-4bfe-a4b7-f900a2f3d23e.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/24435118-366a-41d1-a467-e5378de100d4.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/00f3a73b-1801-43f7-992d-38338ec58a90.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0e972c53-45ac-4313-a3c9-ffd5656b9619.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/296b0b03-c75b-41f0-8bff-1dde57a80e22.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1ebb908b-d5b5-478e-9a91-107476ec3cc2.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2f166fe5-26d7-421e-9c42-4b2e805cdb96.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1a6741c4-d9b2-42d8-a442-002e60565e1e.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2b4e2c18-847d-45e7-a00b-6c972393631e.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2cafaa81-87f2-40e8-a7df-947de34103b3.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/03ff2e8b-e8c6-4a63-a426-f06c9a76d1ac.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/025d7915-74a1-4d0e-83b7-d2cfc1e1ac54.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1a5a0811-72c0-46d3-a883-cf2d4fcf10ce.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2f0e3cf6-b2cd-4e6b-834a-38463ad413da.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1d01a9c3-e3fc-48f2-b78d-6c82223d40be.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2b47029a-b0e9-4d5a-807a-62c8e2d36855.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/10aea5ae-b0be-48e1-87cd-477c15a85772.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/25e0c806-3608-4b47-a1e9-f6f0c7787eff.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0470a3c3-5ae2-4324-9460-5720aa55a2e6.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/290132ce-cede-4fcb-82a2-69a106ef9576.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2cf52eb6-785e-48e5-ae35-6b40da8d024e.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1290a3a2-1908-4aa4-9ec9-60eb79efac1e.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2d70844f-b516-43f7-8bdc-a6d56b5c81de.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/12d70948-c153-45bd-9942-e6cc07d54d07.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1c36091c-041b-4a57-b833-046c6eec605c.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/295e7fd7-dfcc-4945-a8bc-b7bfcaea26ed.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/27c398ca-1fa3-4484-b3d5-1becd99f6105.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/143cc465-80b8-484c-ba71-ad362ea8fd90.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/204d03dd-3faf-4c16-a432-a139493c2928.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1a27e565-b0f5-4419-84b3-744712cb705d.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/28cdfffc-0cda-4f89-9d11-c3705ee51f75.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/219e8604-5624-4059-92c2-401e528484e2.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0431b96a-9e84-4d8b-8e9c-b28c91e10f4a.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1c816e73-2729-4c33-8f2b-54536c4402ee.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0d88a37a-d8d8-4f64-b2f1-7288acf8d80a.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/201e5036-cbcd-47bc-8fd0-5558eaeda272.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/034c963e-7d6e-4350-b2ff-8e534ccf562d.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/3038ffea-6002-410e-86ec-f59a5a306526.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/009c7a22-8272-4acd-a1ee-03de8d420b11.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/14cf8563-6ed2-4458-8659-cd2618a74f7e.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1a64a0e8-b87d-47bc-b7b7-3d18cc06d0b0.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2c04746e-07a9-425a-962f-77373cd87c87.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2b54e5d2-8c8e-4b8f-8128-ab0fa4a7744d.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/c036f4b6-e060-430c-8ded-55b7f09ae43d.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1ffb8eee-5a79-48a8-9f14-eada75c26c19.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/30c0fddd-fda9-4889-8e7b-b13602c6d1b2.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/15443e86-b8c9-4fd2-81f2-390a6a0fffa4.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/27c8ee6f-a9b3-43cc-a976-954c5caa0c26.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1177af10-f84a-4574-bf9f-36475010807a.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1dc404a8-607e-4afd-9c26-d788d9950a93.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1fc7fea2-7b2e-4fe0-a74f-6f7e6ba86e4f.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0f5f6270-8811-4bfe-8ad6-cc6e1f3a786f.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/c0a533e9-21c9-4c3a-9165-410eaed5b294.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2115a65e-319c-4ace-af8b-0617af31646a.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0dcf2fda-af28-4473-8ac3-47bb30d332a8.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/027301a0-cb61-4431-8736-503d0c23cd48.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/018b01e1-7582-4141-949d-0c53d8f6806e.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2bc0753f-a2c9-41c0-a251-a7c8ae3f9292.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/136f6abf-1300-4b93-9b5f-9dd7770f4c97.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1a322302-f652-4697-b332-626c59333d51.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/285b5785-cab1-4713-b345-51dc7e5bde93.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/22c5cde6-2fa8-4a61-a313-17dd471b2234.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/279433ff-5347-417b-ab70-51f06e227130.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/037d1b26-3dc7-48c2-b93c-214e7538c76d.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1ef1ca84-8256-475f-9753-a32b5b17245d.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/27de550e-028c-4e17-b504-a62305551aee.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2698f88a-e222-48fe-9488-99a08e517b7b.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2efd4438-6385-4c97-8869-82c83e739756.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1bebe474-0785-4c45-8546-8c3f9203ed17.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2d17ce84-86f9-4153-8d91-3a75ffe303cc.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2df29894-5303-4050-9b98-a3e0b654b464.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0165543b-85d3-4dd2-9e93-6c5ab10f13da.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/252841f2-7c5e-4554-8181-0c651a885d41.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0d53594f-65b0-4d99-a5d3-c9568c8c6b56.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2d9fef3e-7129-469a-97e2-b2637fff3124.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0175314a-05e7-4ada-9f27-7b874f29842a.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2977d766-7faa-42d5-943d-ec65ef284430.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2bfc6b06-b180-4b11-85b0-e349e470e9ea.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/052a7efe-e167-4c21-bac9-7151f524642b.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1b07d941-e451-4ec8-8c64-f9fa43d5203c.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/13c1a2fb-dbca-450e-a488-9b48a824889b.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2d907148-70a5-4848-a0da-6f40473deef9.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/04fa2f57-3f81-4630-adda-b3d7529adb49.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/28232a23-415f-4f4f-bef4-248f5e875438.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/28359f7d-723c-4907-92b2-7db519775716.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2f51fab1-8b63-4620-a888-fdb75f3e5388.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0ea1e7fa-5d69-471e-9655-69542b15d3e7.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2e03e987-0877-4c41-93b9-a7f3bc74aec6.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2acddcaf-1121-4c5a-8891-b70a7b5b3648.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0107871b-1095-4cd5-a197-bc7715873cbf.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2aec6d89-6abc-4fd5-9ed2-a5126b7becf6.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/04269ea9-d43c-4f01-a72a-d340fb49ff27.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/03cc6b7a-4eef-46e3-98e0-fe3990325b36.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1d2ed7a9-979d-4508-bc79-1b0c77693111.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2e1220d7-1c72-4afa-881e-5380d356bca8.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1defec61-9293-49ff-81ae-7246c77d489c.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1143ff94-7f23-47df-b327-9c1dacd3f0a3.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/27e2e08f-207c-4534-8da7-412fb7868a8a.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/26a56a50-4306-409f-9b63-79e8c8ebba41.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/30446bad-6b8c-4067-a008-6730efa1da5b.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2bf2fa51-11fe-4b7d-afa1-3b373fa2384d.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0da4074c-fa4b-4450-81b3-74282d6c49a6.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/26aff776-ff9d-40f2-b899-6b88f1355506.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2d0cb523-9de7-41d3-98a1-d8fcd371e28d.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/20563db8-4509-4d84-93e0-72d19c2ad6f8.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1bc7bf3e-8ced-447b-9569-a4c0370d8e4c.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1424cff0-1e19-457c-9f48-0237ca60941d.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/254b1774-3219-4a4e-9486-203b1867fedf.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/14b8f48d-f637-47dc-8d93-5ffb65ca2e18.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/28521ba0-b6b6-47ec-a1c6-3449d2ef2fad.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/c129ed85-8cdc-4505-972e-661a36fd9234.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/010355fd-a8c0-4503-993e-16412a3b8136.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/3138294b-6fbd-49da-b606-f0c4f765d9d8.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/20e6c681-9559-410b-abf3-cc0b0d71889d.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1f0056d6-a405-42d6-a088-123ed42bf1c6.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/29f4ade7-a785-419f-8d39-9c7d57f3a296.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/02eff1f9-5830-4e4f-a68e-822ac02047f7.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2ab3187d-b284-4779-8192-d4ee7f147c47.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2d5f9a95-1a11-4471-be50-b6dabf02e310.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/145fe573-db6c-4b16-bbd6-9b34f2ce4c1c.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/22684349-817a-4855-909e-3765dd94a1cd.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/bffb0d66-0f20-41a6-bfa9-ca8acafd378a.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/25172e23-94bb-4f9d-853e-a4a1d934491b.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2bcc5188-113c-4c20-a0bd-f1c19f985a45.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/281e02d7-5a23-4cd5-96c0-923faa21434e.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/14aac35d-3205-4861-8bc5-eb37d90f8298.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2021bb8f-9fad-4220-b7a4-73894f5dbc19.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/13d09f58-c52d-47bd-bfdc-c72321fdeb3d.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/27a589e8-146b-4a85-91fb-8c27f529bb1a.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2f12b716-4c79-42d2-86cf-d1954ccef413.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/04b196dc-81cf-45f4-9180-e6766614599f.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2f646733-0892-48e4-a5d3-1bf84c892052.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2bd7a6e1-bc2b-402d-801c-0026d21e81bd.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/229e6cb4-e8fd-43ce-9ab9-5ddd95e28d2b.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1065459b-6495-4341-9e2d-b471488c3256.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2b9b510d-85f2-4c82-a742-955d2f4fd17a.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/00ad18b7-06ee-4c4d-abca-14bdf814e8b2.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1de5547c-646b-410e-88f4-8797db5da125.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/10dd06b3-dfd5-4bfb-b2d2-184e8fc4d9be.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/11e44a67-9076-4adb-8ba7-497c39c1ac85.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/26c07956-e243-4d83-82ea-b8da718b0e53.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/05b2cc6d-8a25-47c8-a191-bbaaadf0bf64.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1de362d4-8e6f-4d76-9c4e-9436728add4f.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/c1bea7c6-14cb-483c-b2ee-e958901f0667.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2f4dcc33-3ccc-41ca-8b33-9db707891518.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2fbac962-a13e-46d6-b924-57c5e089fd15.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2a670192-9427-46c5-843a-943dedf6ac83.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0ff3dbd7-8d19-4129-9c8e-783b7644c750.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2b39cb1a-d8fd-4227-a74d-aee511b66a58.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2cfda55a-6021-4740-a2cf-89abb2909762.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/312ce1ee-4aee-42da-96dd-0371a8430824.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0f1f2c60-536e-4e50-b9f4-b90cc8c4cc2b.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0597c805-8002-459d-a02a-24240a5c18cf.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/24a25154-88aa-4f08-b04d-372533f281f8.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2c5ecaa4-5235-43e9-8a7f-83b4f62e683a.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/26ca1b4d-b59a-4933-9d80-d732c06ea93a.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/265c655e-b97d-49b0-8b5c-83be37c0b80e.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/136d904b-6dd5-4ef1-a504-a196dfbf73c3.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2c543fc5-9506-4853-8643-d9f9b5e8b318.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/12c940f0-3238-452f-a653-f8bbdbc4670e.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/309c1bc5-eec3-478d-9dd5-e5fbc34c057d.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/303c255f-fdf9-414e-8463-4b799f5839c4.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/057e7feb-bc0f-4a17-bde0-3b9c20727e0e.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/13951087-5cda-44c7-9624-037c3ae8404f.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0382a252-b1b3-477d-bf8f-15da22a7f19c.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/239d9e47-c755-4aea-96c9-18b963878979.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2289fee2-698b-46d5-aaca-00818824598a.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2a38a2eb-9a5e-479c-9d60-40f55b4f4f36.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0cdee6d0-ba84-434c-9d0b-8c570c6d6149.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/306f9134-2913-4da1-bf7a-36873b83d5ec.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1376ccfc-b223-4a54-b682-6fade7355657.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0fabf2e4-de44-4ff1-9afd-0593d4501ef3.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/14b51a44-118d-42ac-91f8-f072f3eacc7b.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0310b580-0ba0-4b74-9de2-db046feddaec.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0094c2b8-5da2-4e25-a177-b4eea16bd671.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/22c2a3d1-252f-42bf-bf1c-f51427ab5640.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/c12bf14d-8ac3-4c9e-a739-3789dc17d067.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/19d67232-2d92-4486-b9bb-f8355f5d2a74.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0ec7d9ce-ff6e-4160-8c20-d6622096114b.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1f2faab3-bcdc-4f7f-a8a2-d4e65b93da3e.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/3129f567-c659-42f8-b4e1-8a5e3827b477.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1d997b6b-b9f1-4dd6-ae12-7a5771e6e873.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/28df756b-3b5d-4ab1-baac-de295460d632.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0fd95a7c-354c-4d5a-a950-af113d04c15d.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/230422fe-3a39-4bdd-ac65-70572f14451c.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/27f321f6-9d3b-48da-84aa-02174c664582.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0f227a5e-7cd0-4b8a-ae5a-7c089ce1d869.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0e64b83a-7b7a-4bf2-9787-08cc6ca0c951.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/22ff801d-23e2-4638-8297-b2b6e40b6426.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1de2a7d7-2601-4d9d-90db-484bd3f41f7f.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/c16a0985-23a7-450f-b10f-f5514e9ec746.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2b2a11b2-12b5-48ce-9b3b-39c91f8a691d.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/129c5c38-17a8-4318-b118-a0e3232da1d5.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/11112783-2e0b-488c-bfb6-f8c7c782baa3.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1d88d652-4e0d-464c-b314-3387e45580e9.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2a5d326c-a979-4704-b4e6-5642dd89f8bb.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/27d57204-7826-4b9c-8eba-a62687bc9ee0.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/29d959bb-171d-487d-87b3-8637e30ba480.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1b5d4e8a-f205-473b-80b5-abe2ad83d715.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/250d9e6f-afbb-4188-b61c-50e669ded9d2.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0cfb46bb-a283-452f-80eb-1ed0404c9eda.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1f7fe736-3806-4995-938b-46b86b764c2e.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/26902670-d4e8-44e4-b750-5e95cf9dd3d6.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2b07bf92-761f-409c-9f56-d85fd0b33a43.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2a731e8d-4b28-46ec-b22d-01cbcbf67d12.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/28531cef-f479-419a-a6de-82e45916534e.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2049f0d6-5c21-4fd8-a74c-997e096e71af.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/00ca48ec-39b3-4650-80ed-1fab342aba0e.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/28b36eb9-398c-4e2d-8994-73c64519b7ec.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/014a7eee-8245-479b-87a9-a9402c66502b.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/139bd334-c207-415c-9fbb-7e597d559c5e.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1dffae5c-df93-4447-a88e-5abb578ef400.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/29fce23c-0ef7-4d05-87bb-b14d7b15db69.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0e33ac1b-a76c-4e1a-b404-9bec63c25528.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/23a2d9c1-6dc4-46a9-9ad8-c53ad5c8cd22.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1b157958-b600-4aa7-98d6-f711a333d3f7.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1b57e19b-7d20-4bdc-892a-4ebc6c8fc67f.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0133cd26-6796-48d3-a092-adae7ce07d61.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/10276fad-8690-4e43-8221-dd01bd77ce7f.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/274c940b-9c97-4aaa-a557-f8b97de6c268.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/037f16ff-46b6-45bf-b737-74072c46fab7.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0e530c69-319b-413d-a9f3-2eb0810bba05.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2d4d4aae-bbe2-470d-9f9e-886a0ac63ff3.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/28d9e106-c5b7-4f30-ad0c-dccf0f8ba09e.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/24f93f6c-5d66-487a-a9a6-3bb4ebf749bc.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/03ae3399-3ca3-4e4e-bf4e-5e5d57dc20e3.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2616499c-8097-43cd-8864-575ba5d4d932.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/200c29e0-0373-48ea-b14c-4c811ad0f123.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/24646647-6508-47ec-b527-eba27e8751dc.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/126d14a0-995c-4e32-ba29-121c7ba2672c.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2e18279e-0068-4ef2-9c10-8bbb6fc9272e.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1c6cdd43-a38a-4464-b012-bc0eb9e73fd0.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0ea07d0e-43cd-485c-b205-0da9897cd3f5.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2536f5d6-d9c1-4ba7-a63e-ce053b28b0e0.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/274d7de6-af4c-4195-921f-2826156b7b5f.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1cba8c35-1b13-45d4-a7dd-9ef2ba5b26df.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1c8e654a-1515-40d4-a0bd-790b24d8cd15.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/275e46bb-1b6e-4186-9486-6b5e1b5a1446.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1e493a0c-8faa-4901-9e17-8598a0380ed4.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/313a472a-b7c6-4e89-9bc4-ea83f4633d25.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/00525b72-7c03-4328-9c02-6393704810d8.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1189ff25-fae8-43e1-aefe-a2a67052c52e.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2b14a096-e4a5-41ca-85dd-10d7863caa63.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/24d7a347-1f05-49d3-8aa6-3b0eeb486807.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2824b990-3060-414b-93b6-40e2ca9067ef.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2f589606-445c-4933-a766-fcba79020784.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2c5202c8-c08c-4d3b-9131-4697062b76b1.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/c0d961d5-159a-497a-8b6b-f65ac28b35a6.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/13a84b9d-6351-4424-b19c-c745ef755dd2.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0322a3ad-3e24-4e6d-8f24-b68e3c61d88f.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2ab5ad27-c2cb-4e6d-b6fb-bf902aec5b8f.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/19fb7d5e-8ed4-4746-aac7-008b0b8ea700.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1c3c0726-8394-466f-a410-9e990b681fc4.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1ca9751a-bbbe-42aa-92b9-ab90d3ecca25.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/205ff415-45e6-4b0d-b9b3-321532ccdf86.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/206955df-8dba-4529-b71c-46daba6ddd00.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2a655317-ec64-47b8-b3ca-6b347b7aad2f.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2d5836dd-1753-4f27-8c73-e6b5a459bbd0.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0105b36d-2d7c-4431-9b5b-fa6acb31ee1d.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2444fb77-294c-49ca-92f1-b79f09c06ee2.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/021d0bd9-560c-43de-80de-5efa191f3251.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/241a8db0-7e96-43f4-ab8f-e3c4f63e1c74.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/043711b3-ff14-463a-b38a-6f8e2d0b1a9a.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/126a05e4-2be6-464f-8f6b-dc1a4e4b1103.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/19f44b85-fe93-4489-a98b-1aa375b3923f.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/02fcdbb1-2ff5-41bb-a28f-a0e5d9a83d51.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1f5d4203-5328-4461-b007-14063909902e.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/242bcc3b-ab55-4f12-a414-00384ba48e9c.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2cdd0947-ec15-4210-9abe-3fd3d6cf4729.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/01478a83-71ad-4319-83b8-d0093bd22dfb.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2433372f-a327-49cd-836c-4db1494a96e5.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2170fcb3-ac43-4128-a256-dc58c3f7381b.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/c1526e12-28a6-429b-98e7-8c6d634a9818.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/266490ca-ce52-4f5b-92ff-082dae7967c0.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2114aa76-4a8f-4061-8950-bf80bcfca0bd.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1cc993a1-83e8-4e17-80a8-90c79117df6f.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/30e38475-ba3a-40f2-976f-b73908861f3f.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/139086b8-d4bf-4ee5-8027-cb405da2c2ab.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/c127904f-d321-4d79-b02d-599b73b0a734.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0d2737a9-4f7c-4e6a-b37a-a620bce1bf8f.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/03055987-3303-429f-8979-cecf701707e5.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2d3442b4-85fb-42b5-a095-9b1fe2c4d371.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/304d9302-cbbb-4026-89e7-7df7da41e422.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1c8a687a-d964-4e5d-8f30-55781771936e.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/24579c4e-f0a8-4a69-b3b2-17867dc928d9.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1e9ab6d7-8cf5-48dc-a30b-afcccfc339e2.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/24e41a67-aee6-4ee5-88ab-dec36b64836f.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/23c605e4-a488-4406-bdc5-55be617b17f5.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/13780fd9-39d8-4758-81cb-2e05c4cbd91e.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/c1acfe9d-3e90-414c-809e-72c6dc153708.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2c8a875e-7e0e-4137-848c-c39fc7677db5.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/291fafe8-0596-4080-93eb-410225f69d86.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1b6095ed-ff63-4aad-92b4-9a9260678ac1.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/245c046b-5ee7-48f0-8c5e-df7f3151c46f.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1cef67f6-69f2-4e9f-9bfb-7fbbbd0012dc.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2ea32c58-de2a-4085-bd7c-7b158bd681c8.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1f670057-5030-4549-8a10-392fb97f520f.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/14fbeb03-cd8b-4d53-bb2a-40e08aced390.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1bcf1a2e-c010-41ca-a15f-c0e3aab1fe51.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1d27bf33-c15e-45ed-aa3f-fbec202f685e.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/201508e7-84a0-4df3-ba82-87b6d200acd3.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/301bce09-ee2c-45a0-9e33-89763a7bdc61.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/11d0ddf4-12c0-4998-a16c-f35cd42e2ad0.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1b039597-aeb2-4409-b39d-df8729c46c56.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/29ccf633-6c21-48e6-8fba-fd95691d8384.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/255952dd-d7d1-4329-a713-43039c15e2f3.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2de21def-1d19-4204-8189-6c4ce33a5aec.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/13659019-299a-47bc-ac85-25500b625fde.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0f7c5eb5-3cd5-4495-a5d9-9a2b4eff6165.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/04bc24b8-8416-49d9-ba53-df71eb1c4c93.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/13cd4766-358d-403a-9b39-d9909e79f78a.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1263a9b3-0492-402e-a152-42a024955a68.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1510b788-b081-4600-8d76-d9cb55590edd.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2a31df3c-5131-4622-b63a-be9a058837bd.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/04bccc40-9a80-419a-9210-bd3c2114754b.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1c3f2cc0-4c64-43bf-828f-8d52f7c5a442.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/c002e66e-aaf3-46ad-b1ce-1ab12f795c80.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/02186c9c-2598-4b9f-9752-b0c9e7c9128c.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/123db563-c75b-4670-829b-11a29ff24617.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2aced5e8-cf72-4f1f-a8cf-707de0a1ddca.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1f7a058d-0e7b-4273-adf0-41bda220208e.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1b6e20c3-5ff6-4e86-8856-2f62539591b9.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2975a1ea-26b6-4aef-95e8-a2f914bcb087.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/24a4f617-41fc-4abe-bdd7-ea28778a0f36.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1f33f831-62fa-432f-9836-b5b18624ff4b.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1b560be4-be73-4976-8d09-06f2dc181701.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2a32ada8-3fe8-4db4-865b-83e6f6f38180.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1368a45a-8fdf-4ae1-9d41-323dc06810ca.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1e367b6c-f5e6-43dc-8992-d97554c7f2fb.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/23262e9c-3767-4beb-8e3d-0d1d50df6d8f.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/03d837fb-4528-4e56-bf4e-58fbeae187bb.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2e00f7b7-ea1d-4da8-baa1-ffcbcc60be8d.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/23505b01-62da-4e56-bcdd-1adefde2cbb9.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/c1d3ec0a-8dc1-440c-9f5f-f8de703418ef.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1dba90ae-6022-4c9a-865c-323be484f911.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/105a84d8-760c-4158-9399-4ae9127ab813.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/141fe03a-61be-4ada-b0d3-8699f729d2ec.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0092f442-ccb5-49a2-81cf-b6ca3f829a53.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/10fc4fbc-0aad-447b-a9bc-88e840b409bb.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1a4d2d2f-34c8-42cb-a432-9c46bb7a8988.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/25b48729-772e-4742-80fa-3763b787d87d.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2f27d72f-4e93-482c-b52e-d15db6e66d9a.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/020d940f-e100-4c82-8f44-58174dc28684.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/21698e32-6477-4178-bbe3-9e538d3c9d6b.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/28c25252-860a-4f65-ae97-c136b577da2f.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/23414dbb-910f-4d9d-9c4b-e47d6d0b4853.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0332bce4-6181-48a5-ac40-b426f50abcc4.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/26e868a8-8364-4d43-8c22-736de9e5863b.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2b96d291-2dbe-4756-9d6c-d23efcd863b8.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1010ee15-41a3-4533-b5d9-d8f26946160b.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2a488e98-8e13-4d63-971e-dc9d172beb2a.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/19b8517b-24e4-457b-96c0-a457e30125bb.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0140cefe-d9c1-4de5-a59b-1aad98e4b62a.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2971548b-c2b1-4b9b-bf50-00d7cc78f096.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/25840be8-f6cf-4df1-893b-80412b99a417.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/03a75f93-bdfb-4e5a-89f3-548b04fdbb5e.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2ebf08b7-83db-453f-bba8-9abc4caaacd1.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/12bc974e-550d-4ce2-84bd-467733c8f388.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/05a79b29-88d2-4782-a0a2-272e83890e0e.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/28b6f49b-3660-4836-9c68-e552fdab7917.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/23fe0fe9-6021-401d-a981-9c9766bf96b9.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2fed6de4-af54-4b45-a188-17ac855a7360.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0f62cec3-0d14-4a7b-bed3-230a4a0b9b3d.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/115798c5-2cc7-4ad7-9619-15f95d6dda9d.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2f279550-0173-4db1-a57b-c1af4ce6060a.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2657b0a9-63ec-43b2-810e-b665f879f309.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1fe3ad5f-28d1-4d32-a67d-e9ba8188cde7.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/014f2256-b71e-4168-84f7-bac69852057e.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/11c7074c-e357-4032-b2e5-66a67d330545.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2fed3ad3-93c2-4700-b297-451313082bca.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/00b4ac1b-fa09-4dbe-b93f-7d9e52992a68.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/25807932-ae56-4b41-8d11-6c7eaf18b81a.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/21f202b2-fa91-490b-9e48-8cb38078a7c8.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/133b12ec-d8af-48d6-8c4d-4cf3e92eabb5.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/c0ec3097-a14b-4ee2-9547-c0d2532f2e62.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/016d6d63-e32a-4df0-ad43-e42f808ab480.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/11a04d2d-4f12-4876-abd3-baff3797e66e.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0490b4dd-cb7c-496a-b0ea-12244a055d57.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1f69bd0a-8e25-4c4e-b5be-f4395f032f58.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1a966ab3-4029-4cd3-aa38-70a2f5f8e6ca.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/13f6df4f-9b1c-4d25-ba93-f45df7f0e4f6.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2c76c5ad-25c6-4987-ab4b-95f425a9dd79.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/231c9104-2a52-4299-a457-46220d7721d5.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/010be344-5412-4cc8-afab-fb07f29e3356.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/056aad32-f0ca-41bb-8153-9bb2904b5658.dcm
# ...
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/21d231c5-d903-4acf-ab7e-b7bc7ea009f1.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/02952fe2-ceab-4e55-b1af-71f40a209a1f.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1c04333e-0911-447d-ac17-173ac4a27e9a.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/130a294d-b0ce-4602-a863-60720c12aa00.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/c1d9b4c9-39cc-4b37-b95b-82d26a1b68df.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/302451eb-3ff4-40a4-ae2a-e37ebf8b6d4e.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/00679577-c370-4aff-ab2b-fc4846c3eabb.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0db01d52-c8d4-490d-bf26-611a5a7616f4.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/27016559-e694-413a-bc72-ec9fdb9c8bee.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0eabd32f-ebe9-4f0b-8307-3633f93a0e3e.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2cf1426e-9663-4c08-b37e-960e53f1225f.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/124cea62-1b6c-445b-b34c-99e6979d0316.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0dde0556-d227-4e56-a703-7791fb290b64.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/131e619a-f15c-4c89-97fe-64c484e17834.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2c929ddf-362a-4701-8501-2ee7f6abed22.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/23b839c3-ece6-4daf-9b58-c347c598d42f.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/23212cd1-662c-442e-9e1f-5364e2c78384.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/23fa2526-f011-4de3-b8dc-b76b47406955.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1a75516e-b987-480d-b4df-61505f384506.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1a941593-8eb0-41dd-9763-da1a1c874196.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/22b656bf-8c47-4edf-8e99-4ab9a195424f.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0fb9236e-e8bd-4dbc-81a2-c062caafdf43.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0f9d153b-7f89-40cb-92c7-2f7a7d423547.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/bff4d9e9-8206-4109-a2e8-4c2aac78404b.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/c01261ad-12bf-4ac1-8621-96881a939fd6.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1270a024-bebe-4b8f-8702-f029f51d532e.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/144fcb63-98e1-47a0-939f-2a4b1bf9ac07.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/272be76e-0270-4c10-819d-c32ec14ade4b.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/02b7bd21-0ca3-48b0-b98c-dd85a7ad1c0f.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/02c19fee-bf32-4969-8ba4-7e996f1f9f3a.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/038cd87f-d57f-4db6-9548-879dc697d656.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0107394f-5672-4969-8a15-279714669f63.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1e28e969-5c77-4046-a1ea-7f7f70d616a8.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0591bb41-c6f2-4c5d-afbb-4816867c5305.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0f923d95-7046-44ed-8aa7-243c0b98c881.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/12c1a551-d9f9-488e-9454-125b469899d9.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1b824b02-93a4-4656-9625-356752bf67a5.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/208a6648-73ce-4de4-af7d-19c703d9200b.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2b3a47c7-8fd9-416f-a9a9-04388c11546d.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1532c43a-028c-4d77-9cb0-f9d103988e7b.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2ea0e3dd-d671-42d0-b5db-0d73c79b4b82.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/c0581ffe-dd70-4b94-8c20-7755e12b0dfa.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/28ffb122-43cd-4ae0-8b00-880213e68361.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/12d17a68-14af-4b15-8b8c-10dd13630f2b.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0eb58a9b-834f-4962-abfa-5c13b8a4b3cc.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/211702c1-a91e-46b5-b3d9-6669212a7fd0.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/30b8ba34-b0b3-4def-8b28-a169221d755c.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/c107a573-4b0f-4b31-9ad5-f33279364ff3.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1da66526-8236-4948-884d-ee55f117bff5.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/15212951-d7a3-4332-8fc9-51ef843a6ade.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/28715b54-8198-4bac-b86c-cda1c039b7cd.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1c0cee97-fb9c-4921-979f-e17a323f6d6f.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0ffb49c2-51e5-47dd-bfb9-2fe300e697e8.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1b435cbd-9ef2-4f8e-b2a0-39cad1fd1962.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/04749fa3-5cb1-4f37-8156-f73a2083b392.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/112c8a69-cfec-425c-b9d9-fe07a0fd4ca7.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2b5f9923-0ee5-42cf-b6bc-5d16ac75e9ae.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1342a8a2-ca78-4f73-93f1-01c07b298c8c.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/26903582-dbc1-4427-b9da-45e2fa00ed17.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/14856277-5e29-4ee1-9b7c-261802d28b0a.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1f07ebba-bd60-40e6-869e-ab5e47340f54.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/20d9afc7-a8aa-414d-9e44-fce8775b0dbb.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/23737a3d-f39e-4c71-96d9-37cac3c72004.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1c9dd5d9-c943-4b9f-a885-a1f8f5da07d8.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/3140ad27-ac31-4bf5-b74a-e2742ba630ef.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/265f1a4a-fee4-447e-9709-0fff15f2255b.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0dbfe0c3-ec45-404f-ad6e-54683f28b52c.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/285f57d4-98d5-4d75-b91e-cd21ac0ef1a0.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/270e6509-5f4c-448d-bb55-822343311cb8.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/208c6592-2055-4cde-98c3-dd48419088e9.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/13060344-a70e-478a-8754-378e72ba00c3.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0f47abd8-8c3f-40bf-a991-7d97ff1eb083.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/004f0a0f-fb54-4068-8b67-d3eef6724f44.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0452d6c6-4693-4ade-8b20-46e09c719ada.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2c9ff0b6-2ec0-49f6-85f4-54b424c9df7a.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1c4b74c7-3a48-453f-8f79-2f58cdccedfa.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/00e42241-12a0-490a-b856-db3e4ab41104.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0316721f-901b-4828-a1ed-c7ab71a0141d.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/224218a9-be4d-4564-9f35-8a4d1b5a1f41.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0e38f5ef-e94f-46d2-a67f-d3ca284e4351.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2b730fcb-2568-4fb2-8964-98f4c171142f.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2bc676d8-9b52-46ac-bf77-40a8846326a8.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/10af7d7a-04cb-4805-9ce8-c1944f8558fd.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/208db98a-049c-48ed-815a-5bd6f6d2b8af.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0f0cb093-4030-4f30-824a-dc15e4d3d778.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/112b8a2a-9c9f-42da-8b2b-d342db8d28c9.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/059cdbab-5cdc-4b42-bf37-0423ae3eba0a.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/21bd7ee7-584f-4b18-98ce-38a7b76b644d.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0d55280e-edd7-48dd-bfce-7cd44ecfb3f7.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1f0fc732-7f83-4ff0-81d4-dd7ff590da76.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/21271204-1954-43bc-973b-63b896c17374.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0e1664f0-f707-4bf0-9a33-4cc849e25284.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/03bc6e8d-73df-432c-92be-9f6fe2eb7e34.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2565d222-7628-442d-ae1f-af5cfab84559.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1e805c68-9cb6-4305-914b-5a0d5b60097e.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/13ece116-aee5-48ab-abce-71b194f1a5cc.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/298c9dbf-f493-4991-9f9e-1eeb3c570bed.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/00c67fbc-35f6-4058-88b4-4bfad19014ec.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/c1f55e7e-4065-4dc0-993e-a7c1704c6036.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0124f347-a386-462e-ac00-4b3ddb2ed159.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1f1a0bd2-7589-442a-be91-3c284020fae7.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/289578c9-2d3b-4571-ba3a-5b7e2b5cbd6e.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2622cb49-48e6-47dd-9031-bdbf4467ed74.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0f1dc462-55cf-4c50-9ffe-16e1cec3cb79.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/c103f115-266b-4f0c-97d0-082dc2438a27.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/150edfae-719c-4c35-8947-b226130bd3e8.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2331d0f9-b2b5-4cfa-ba65-e221f09316f1.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2c96653c-ddeb-419a-ad37-8836eab89773.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/20f708ac-0e1a-40fb-908c-5091f4a4c08d.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/14af3bf7-619a-4244-aca1-4bb510fda544.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/216bac30-0d82-425f-ae57-eb6c2fc01271.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1f8ab482-338a-4b66-837e-a6c510e18607.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1378f79c-6ea0-41e9-98a9-1b15c2c54a7d.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/235170f2-8229-47e1-bd51-0b3d42c0775a.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0123ddde-aa60-4364-a3c5-2aed75bba3dd.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1f55113e-db6e-4b97-853a-7e8f7e1fe451.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/022a1092-db63-4f8c-a7fe-77019dd4c52e.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/284b4ebc-64f7-469b-8b6f-79a9fbb964b0.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/c1d1a7c9-94b3-44e3-9353-3ec35fce7d70.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1bae405c-b6f0-4cc4-ab7a-e09362a7ec07.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/0549f9af-5fb2-4ec8-ba65-5c5c8cd79a2a.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/11d313d4-1d96-4da8-8fe0-8a0db9910d04.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/034e373b-aa5d-4464-8528-a280a42bc651.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/258e3a11-ea93-4312-8efe-8cd0e34023c4.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/23515be4-852c-4d17-af03-c338ab35f427.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2bf67143-007c-42e1-b0ef-24176e09a9cc.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/02b42e7e-d0da-43b7-9a54-458264099d08.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/035c8891-656e-4422-82a0-a53406dae9ba.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/02eead22-409f-4d50-ae60-e8996493a111.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1cf84380-a3bd-44a9-9c4f-b5d51203a97b.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/140ebc5d-5a15-4948-b698-0a4b32d12a93.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/233e0be9-7a88-48f7-b5e3-af50cb2ccb4b.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1307e549-4650-408e-b731-9a8b07b8087d.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2189bf86-a0cc-4aeb-9320-273a6236d10a.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/26586d01-b992-41c4-a7a4-c9f1f8d102ad.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/23ebfb85-2312-4a8b-8879-3cf48a1e8920.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2dbac7d7-9100-4861-8e15-fa2adf82c6e3.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/19e76f7c-b673-4b33-a385-49f0bb8e4558.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1cb7194e-f761-41b7-8e6f-d5abdbfb270c.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/238375d8-0b30-4ae7-813a-fd60bf865f40.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1ef2bfbf-b68d-4981-8dc3-b5d7b54ad55e.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/1fc3831a-7b78-48c5-90c1-af8971ee9eae.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/20da1944-1714-4170-a08a-8b82c0788ad5.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/13c6a303-2c21-4edf-9dca-4999dafe8a4e.dcm
# /kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images/2b83d54b-af50-4c15-9d53-d3b1c5381678.dcm

# %% [markdown]
# # Approach
# * 首先，使用卷积神经网络对图像进行分割，直接使用边界框作为掩码。
# * 其次，连接的组件用于分离预测肺炎的多个区域。
# * 最后，在每个连接的组件周围简单地绘制一个边界框。
# # Network
# * 该网络由许多具有卷积的残差块和具有最大池化的下采样块组成。
# * 在网络末端，单个上采样层将输出转换为与输入相同的形状。
#
# 由于网络的输入是 256 x 256（而不是原来的 1024 x 1024），并且网络多次下采样而没有任何有意义的上采样（最终的上采样只是为了匹配 256 x 256 掩码），最终预测非常粗糙。如果网络缩减采样 4 倍，则最终边界框只能更改至少 16 个像素。

# %%
import os
import csv
import random
import pydicom
import numpy as np
import pandas as pd
from skimage import io
from skimage import measure
from skimage.transform import resize

import tensorflow as tf
from tensorflow import keras

from matplotlib import pyplot as plt
import matplotlib.patches as patches

# %% [markdown]
# # Load pneumonia locations
# 表每行包含 [filename : pneumonia location]对。
#
# * 如果文件名包含多种肺炎，则表包含具有相同文件名但不同肺炎位置的多行。
# * 如果文件名不包含肺炎，则它包含具有空肺炎位置的单行。
#
# 下面的代码加载表并将其转换为字典。
#
# * 字典使用文件名作为键，并将该文件名中的肺炎位置列表用作值。
# * 如果字典中没有文件名，则表示它不包含肺炎。

# %%
# empty dictionary
pneumonia_locations = {}
# load table
with open(os.path.join('/kaggle/input/rsna-pneumonia-detection-challenge/stage_2_train_labels.csv'), mode='r') as infile:
    # open reader
    reader = csv.reader(infile)
    # skip header
    next(reader, None)
    # loop through rows
    for rows in reader:
        # retrieve information
        filename = rows[0]
        location = rows[1:5]
        pneumonia = rows[5]
        # if row contains pneumonia add label to dictionary
        # which contains a list of pneumonia locations per filename
        if pneumonia == '1':
            # convert string to float to int
            location = [int(float(i)) for i in location]
            # save pneumonia location in dictionary
            if filename in pneumonia_locations:
                pneumonia_locations[filename].append(location)
            else:
                pneumonia_locations[filename] = [location]

# %% [markdown]
# # Load filenames

# %%
# load and shuffle filenames
folder = '/kaggle/input/rsna-pneumonia-detection-challenge/stage_2_train_images'
filenames = os.listdir(folder)
random.shuffle(filenames)
# split into train and validation filenames
n_valid_samples = 2560
train_filenames = filenames[n_valid_samples:]
valid_filenames = filenames[:n_valid_samples]
print('n train samples', len(train_filenames))
print('n valid samples', len(valid_filenames))
n_train_samples = len(filenames) - n_valid_samples
# Out:
# n train samples 24124
# n valid samples 2560

# %% [markdown]
# # Exploration

# %%
print('Total train images:',len(filenames))
print('Images with pneumonia:', len(pneumonia_locations))

ns = [len(value) for value in pneumonia_locations.values()]
plt.figure()
plt.hist(ns)
plt.xlabel('Pneumonia per image')
plt.xticks(range(1, np.max(ns)+1))
plt.show()

heatmap = np.zeros((1024, 1024))
ws = []
hs = []
for values in pneumonia_locations.values():
    for value in values:
        x, y, w, h = value
        heatmap[y:y+h, x:x+w] += 1
        ws.append(w)
        hs.append(h)
plt.figure()
plt.title('Pneumonia location heatmap')
plt.imshow(heatmap)
plt.figure()
plt.title('Pneumonia height lengths')
plt.hist(hs, bins=np.linspace(0,1000,50))
plt.show()
plt.figure()
plt.title('Pneumonia width lengths')
plt.hist(ws, bins=np.linspace(0,1000,50))
plt.show()
print('Minimum pneumonia height:', np.min(hs))
print('Minimum pneumonia width: ', np.min(ws))
# Out:
# Total train images: 26684
# Images with pneumonia: 6012
# Minimum pneumonia height: 45
# Minimum pneumonia width:  40

# %% [markdown]
# # Data generator
# 数据集太大，无法放入内存中，因此我们需要创建一个动态加载数据的生成器。
#
# * 生成器接收一些文件名、batch_size和其他参数。
#
# * 生成器输出随机批次的 numpy images 和 numpy masks。

# %%
class generator(keras.utils.Sequence):
    
    def __init__(self, folder, filenames, pneumonia_locations=None, batch_size=32, image_size=256, shuffle=True, augment=False, predict=False):
        self.folder = folder
        self.filenames = filenames
        self.pneumonia_locations = pneumonia_locations
        self.batch_size = batch_size
        self.image_size = image_size
        self.shuffle = shuffle
        self.augment = augment
        self.predict = predict
        self.on_epoch_end()
        
    def __load__(self, filename):
        # load dicom file as numpy array
        img = pydicom.dcmread(os.path.join(self.folder, filename)).pixel_array
        # create empty mask
        msk = np.zeros(img.shape)
        # get filename without extension
        filename = filename.split('.')[0]
        # if image contains pneumonia
        if filename in self.pneumonia_locations:
            # loop through pneumonia
            for location in self.pneumonia_locations[filename]:
                # add 1's at the location of the pneumonia
                x, y, w, h = location
                msk[y:y+h, x:x+w] = 1
        # resize both image and mask
        img = resize(img, (self.image_size, self.image_size), mode='reflect')
        msk = resize(msk, (self.image_size, self.image_size), mode='reflect') > 0.5
        # if augment then horizontal flip half the time
        if self.augment and random.random() > 0.5:
            img = np.fliplr(img)
            msk = np.fliplr(msk)
        # add trailing channel dimension
        img = np.expand_dims(img, -1)
        msk = np.expand_dims(msk, -1)
        return img, msk
    
    def __loadpredict__(self, filename):
        # load dicom file as numpy array
        img = pydicom.dcmread(os.path.join(self.folder, filename)).pixel_array
        # resize image
        img = resize(img, (self.image_size, self.image_size), mode='reflect')
        # add trailing channel dimension
        img = np.expand_dims(img, -1)
        return img
        
    def __getitem__(self, index):
        # select batch
        filenames = self.filenames[index*self.batch_size:(index+1)*self.batch_size]
        # predict mode: return images and filenames
        if self.predict:
            # load files
            imgs = [self.__loadpredict__(filename) for filename in filenames]
            # create numpy batch
            imgs = np.array(imgs)
            return imgs, filenames
        # train mode: return images and masks
        else:
            # load files
            items = [self.__load__(filename) for filename in filenames]
            # unzip images and masks
            imgs, msks = zip(*items)
            # create numpy batch
            imgs = np.array(imgs)
            msks = np.array(msks)
            return imgs, msks
        
    def on_epoch_end(self):
        if self.shuffle:
            random.shuffle(self.filenames)
        
    def __len__(self):
        if self.predict:
            # return everything
            return int(np.ceil(len(self.filenames) / self.batch_size))
        else:
            # return full batches only
            return int(len(self.filenames) / self.batch_size)

# %% [markdown]
# # Network

# %%
def create_downsample(channels, inputs):
    x = keras.layers.BatchNormalization(momentum=0.9)(inputs)
    x = keras.layers.LeakyReLU(0)(x)
    x = keras.layers.Conv2D(channels, 1, padding='same', use_bias=False)(x)
    x = keras.layers.MaxPool2D(2)(x)
    return x

def create_resblock(channels, inputs):
    x = keras.layers.BatchNormalization(momentum=0.9)(inputs)
    x = keras.layers.LeakyReLU(0)(x)
    x = keras.layers.Conv2D(channels, 3, padding='same', use_bias=False)(x)
    x = keras.layers.BatchNormalization(momentum=0.9)(x)
    x = keras.layers.LeakyReLU(0)(x)
    x = keras.layers.Conv2D(channels, 3, padding='same', use_bias=False)(x)
    return keras.layers.add([x, inputs])

def create_network(input_size, channels, n_blocks=2, depth=4):
    # input
    inputs = keras.Input(shape=(input_size, input_size, 1))
    x = keras.layers.Conv2D(channels, 3, padding='same', use_bias=False)(inputs)
    # residual blocks
    for d in range(depth):
        channels = channels * 2
        x = create_downsample(channels, x)
        for b in range(n_blocks):
            x = create_resblock(channels, x)
    # output
    x = keras.layers.BatchNormalization(momentum=0.9)(x)
    x = keras.layers.LeakyReLU(0)(x)
    x = keras.layers.Conv2D(1, 1, activation='sigmoid')(x)
    outputs = keras.layers.UpSampling2D(2**depth)(x)
    model = keras.Model(inputs=inputs, outputs=outputs)
    return model

# %% [markdown]
# # Train network

# %%
# define iou or jaccard loss function
def iou_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    y_true = tf.reshape(y_true, [-1])
    y_pred = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true * y_pred)
    score = (intersection + 1.) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection + 1.)
    return 1 - score

# combine bce loss and iou loss
def iou_bce_loss(y_true, y_pred):
    return 0.5 * keras.losses.binary_crossentropy(y_true, y_pred) + 0.5 * iou_loss(y_true, y_pred)

# mean iou as a metric
def mean_iou(y_true, y_pred):
    y_pred = tf.round(y_pred)
    intersect = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true, axis=[1, 2, 3]) + tf.reduce_sum(y_pred, axis=[1, 2, 3])
    smooth = tf.ones(tf.shape(intersect))
    return tf.reduce_mean((intersect + smooth) / (union - intersect + smooth))

# create network and compiler
model = create_network(input_size=256, channels=32, n_blocks=2, depth=4)
model.compile(optimizer='adam',
              loss=iou_bce_loss,
              metrics=['accuracy', mean_iou])

# cosine learning rate annealing
def cosine_annealing(x):
    lr = 0.001
    epochs = 25
    return lr*(np.cos(np.pi*x/epochs)+1.)/2
learning_rate = tf.keras.callbacks.LearningRateScheduler(cosine_annealing)

# create train and validation generators
folder = '/kaggle/input/rsna-pneumonia-detection-challenge/stage_2_train_images'
train_gen = generator(folder, train_filenames, pneumonia_locations, batch_size=32, image_size=256, shuffle=True, augment=True, predict=False)
valid_gen = generator(folder, valid_filenames, pneumonia_locations, batch_size=32, image_size=256, shuffle=False, predict=False)

history = model.fit(train_gen, validation_data=valid_gen, callbacks=[learning_rate], epochs=12, workers=4, use_multiprocessing=True)
# Out:
# Epoch 1/12
# 753/753 [==============================] - 1737s 2s/step - loss: 0.4837 - accuracy: 0.9622 - mean_iou: 0.6154 - val_loss: 0.4515 - val_accuracy: 0.9675 - val_mean_iou: 0.6814 - lr: 0.0010
# Epoch 2/12
# 753/753 [==============================] - 1719s 2s/step - loss: 0.4421 - accuracy: 0.9678 - mean_iou: 0.6674 - val_loss: 0.4419 - val_accuracy: 0.9621 - val_mean_iou: 0.6277 - lr: 9.9606e-04
# Epoch 3/12
# 753/753 [==============================] - 1758s 2s/step - loss: 0.4320 - accuracy: 0.9689 - mean_iou: 0.6822 - val_loss: 0.4502 - val_accuracy: 0.9728 - val_mean_iou: 0.7181 - lr: 9.8429e-04
# Epoch 4/12
# 753/753 [==============================] - 1775s 2s/step - loss: 0.4254 - accuracy: 0.9697 - mean_iou: 0.6906 - val_loss: 0.4334 - val_accuracy: 0.9677 - val_mean_iou: 0.6937 - lr: 9.6489e-04
# Epoch 5/12
# 753/753 [==============================] - 1873s 2s/step - loss: 0.4192 - accuracy: 0.9704 - mean_iou: 0.6967 - val_loss: 0.4284 - val_accuracy: 0.9719 - val_mean_iou: 0.6957 - lr: 9.3815e-04
# Epoch 6/12
# 753/753 [==============================] - 1875s 2s/step - loss: 0.4151 - accuracy: 0.9709 - mean_iou: 0.7004 - val_loss: 0.4182 - val_accuracy: 0.9728 - val_mean_iou: 0.7266 - lr: 9.0451e-04
# Epoch 7/12
# 753/753 [==============================] - 1854s 2s/step - loss: 0.4119 - accuracy: 0.9710 - mean_iou: 0.7048 - val_loss: 0.4128 - val_accuracy: 0.9650 - val_mean_iou: 0.6460 - lr: 8.6448e-04
# Epoch 8/12
# 753/753 [==============================] - 1880s 2s/step - loss: 0.4087 - accuracy: 0.9715 - mean_iou: 0.7051 - val_loss: 0.4172 - val_accuracy: 0.9622 - val_mean_iou: 0.6613 - lr: 8.1871e-04
# Epoch 9/12
# 753/753 [==============================] - 1871s 2s/step - loss: 0.4041 - accuracy: 0.9719 - mean_iou: 0.7118 - val_loss: 0.3953 - val_accuracy: 0.9706 - val_mean_iou: 0.7064 - lr: 7.6791e-04
# Epoch 10/12
# 753/753 [==============================] - 1904s 3s/step - loss: 0.3989 - accuracy: 0.9725 - mean_iou: 0.7200 - val_loss: 0.3914 - val_accuracy: 0.9717 - val_mean_iou: 0.7239 - lr: 7.1289e-04
# Epoch 11/12
# 753/753 [==============================] - 1868s 2s/step - loss: 0.3971 - accuracy: 0.9724 - mean_iou: 0.7141 - val_loss: 0.4152 - val_accuracy: 0.9751 - val_mean_iou: 0.7430 - lr: 6.5451e-04
# Epoch 12/12
# 753/753 [==============================] - 1874s 2s/step - loss: 0.3931 - accuracy: 0.9731 - mean_iou: 0.7219 - val_loss: 0.3945 - val_accuracy: 0.9726 - val_mean_iou: 0.7166 - lr: 5.9369e-04

# %%
plt.figure(figsize=(12,4))
plt.subplot(131)
plt.plot(history.epoch, history.history["loss"], label="Train loss")
plt.plot(history.epoch, history.history["val_loss"], label="Valid loss")
plt.legend()
plt.subplot(132)
plt.plot(history.epoch, history.history["accuracy"], label="Train accuracy")
plt.plot(history.epoch, history.history["val_accuracy"], label="Valid accuracy")
plt.legend()
plt.subplot(133)
plt.plot(history.epoch, history.history["mean_iou"], label="Train iou")
plt.plot(history.epoch, history.history["val_mean_iou"], label="Valid iou")
plt.legend()
plt.show()

# %%
for imgs, msks in valid_gen:
    # predict batch of images
    preds = model.predict(imgs)
    # create figure
    f, axarr = plt.subplots(4, 8, figsize=(20,15))
    axarr = axarr.ravel()
    axidx = 0
    # loop through batch
    for img, msk, pred in zip(imgs, msks, preds):
        # plot image
        axarr[axidx].imshow(img[:, :, 0])
        # threshold true mask
        comp = msk[:, :, 0] > 0.5
        # apply connected components
        comp = measure.label(comp)
        # apply bounding boxes
        predictionString = ''
        for region in measure.regionprops(comp):
            # retrieve x, y, height and width
            y, x, y2, x2 = region.bbox
            height = y2 - y
            width = x2 - x
            axarr[axidx].add_patch(patches.Rectangle((x,y),width,height,linewidth=2,edgecolor='b',facecolor='none'))
        # threshold predicted mask
        comp = pred[:, :, 0] > 0.5
        # apply connected components
        comp = measure.label(comp)
        # apply bounding boxes
        predictionString = ''
        for region in measure.regionprops(comp):
            # retrieve x, y, height and width
            y, x, y2, x2 = region.bbox
            height = y2 - y
            width = x2 - x
            axarr[axidx].add_patch(patches.Rectangle((x,y),width,height,linewidth=2,edgecolor='r',facecolor='none'))
        axidx += 1
    plt.show()
    # only plot one batch
    break
# Out:
# 1/1 [==============================] - 0s 29ms/step

# %% [markdown]
# # Predict test images

# %%
# load and shuffle filenames
folder = '/kaggle/input/rsna-pneumonia-detection-challenge/stage_2_test_images'
test_filenames = os.listdir(folder)
print('n test samples:', len(test_filenames))

# create test generator with predict flag set to True
test_gen = generator(folder, test_filenames, None, batch_size=25, image_size=256, shuffle=False, predict=True)

# create submission dictionary
submission_dict = {}
# loop through testset
for imgs, filenames in test_gen:
    # predict batch of images
    preds = model.predict(imgs)
    # loop through batch
    for pred, filename in zip(preds, filenames):
        # resize predicted mask
        pred = resize(pred, (1024, 1024), mode='reflect')
        # threshold predicted mask
        comp = pred[:, :, 0] > 0.5
        # apply connected components
        comp = measure.label(comp)
        # apply bounding boxes
        predictionString = ''
        for region in measure.regionprops(comp):
            # retrieve x, y, height and width
            y, x, y2, x2 = region.bbox
            height = y2 - y
            width = x2 - x
            # proxy for confidence score
            conf = np.mean(pred[y:y+height, x:x+width])
            # add to predictionString
            predictionString += str(conf) + ' ' + str(x) + ' ' + str(y) + ' ' + str(width) + ' ' + str(height) + ' '
        # add filename and predictionString to dictionary
        filename = filename.split('.')[0]
        submission_dict[filename] = predictionString
    # stop if we've got them all
    if len(submission_dict) >= len(test_filenames):
        break

# save dictionary as csv file
sub = pd.DataFrame.from_dict(submission_dict,orient='index')
sub.index.names = ['patientId']
sub.columns = ['PredictionString']
sub.to_csv('submission.csv')
# Out:
# n test samples: 3000
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
